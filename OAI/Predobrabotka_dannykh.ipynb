# %%
import pandas as pd
import math
import numpy as np
import scipy as sp
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
from pprint import pprint

# %%
train = pd.read_csv('C:/Users/Iragi Hikari/Downloads/train.csv')

# %%
train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
class Norm:
    def __init__(self, data):
        self.data = data
        self.columns = list(data.columns)
  
    @staticmethod
    def get_columns(self, dtype):
        self.stype = self.data.select_dtypes(include=dtype)
        self.scolumns = list(self.stype.columns)

    @staticmethod
    def one_hot_encoding_insert(self, res, length, column):
        new_column = pd.DataFrame(res, columns=[f'{column}_{i}' for i in range(length)])
        self.data = self.data.join(new_column)


    def OHE(self, dtype):
        self.get_columns(self, dtype)

        for i in self.scolumns:
            d_list = list(set(self.data[i]))
            length = len(d_list)
            res = []

            for b in self.data[i]:
                own_list = [0]*length
                index = d_list.index(b)
                own_list[index] = 1
                res.append(own_list)
      
            self.one_hot_encoding_insert(self, res, length, i)

        self.data = self.data.drop(self.scolumns, axis=1)
  
    def MinMaxScale(self, dtype):
        self.get_columns(self, dtype)

        for i in self.scolumns:
            dmax = max(self.data[i])
            dmin = min(self.data[i])
      
            self.data[i] = (self.data[i] - dmin) / (dmax - dmin)


    def Normalize(self):
        self.OHE(['object'])
        self.MinMaxScale(['int64', 'float64'])

# %%
norm = Norm(train)

# %%
norm.Normalize()

# %%
train = norm.data

# %%
train.loc[train['price_range'] >= 0.5, 'price_range'] = 1
train.loc[train['price_range'] < 0.5, 'price_range'] = 0

# %%
train
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 0          0.227789   0.0         0.68       0.0  0.052632     0.0
# 1          0.347361   1.0         0.00       1.0  0.000000     1.0
# 2          0.041416   1.0         0.00       1.0  0.105263     1.0
# 3          0.076152   1.0         0.80       0.0  0.000000     0.0
# 4          0.881764   1.0         0.28       0.0  0.684211     1.0
# ...             ...   ...          ...       ...       ...     ...
# 1995       0.195725   1.0         0.00       1.0  0.000000     1.0
# 1996       0.977956   1.0         0.84       1.0  0.000000     0.0
# 1997       0.941884   0.0         0.16       1.0  0.052632     1.0
# 1998       0.675351   0.0         0.16       0.0  0.210526     1.0
# 1999       0.006012   1.0         0.60       1.0  0.263158     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores  ...  px_height  px_width  \
# 0       0.080645  0.555556   0.900000  0.142857  ...   0.010204  0.170895
# ...

# %%
x = train.iloc[:, :-1]
y = train.iloc[:, -1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
class LogisticRegression:
    def __init__(self, lr=0.01, num_iter=100000, fit_intercept=True):
        self.lr = lr
        self.num_iter = num_iter
        self.fit_intercept = fit_intercept
    
    def add_intercept(self, X):
        intercept = np.ones((X.shape[0], 1))
        return np.concatenate((intercept, X), axis=1)
    
    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))
    
    def fit(self, X, y):
        if self.fit_intercept:
            X = self.add_intercept(X)
        
        self.theta = np.zeros(X.shape[1])
        print(self.theta.shape)
        
        for i in range(self.num_iter):
            z = np.dot(X, self.theta)
            h = self.sigmoid(z)
            gradient = np.dot(X.T, (h - y)) / y.size
            self.theta -= self.lr * gradient
    
    def predict_proba(self, X):
        if self.fit_intercept:
            X = self.add_intercept(X)
        
        return self.sigmoid(np.dot(X, self.theta))
    
    def predict(self, X, threshold=0.5):
        if self.fit_intercept:
            X = self.add_intercept(X)
        
        return np.where(self.sigmoid(np.dot(X, self.theta)) > threshold, 1, 0)

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# (21,)

# %%
y_pred = lr.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.97
